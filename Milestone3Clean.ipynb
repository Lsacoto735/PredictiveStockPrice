# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import missingno as msno
import datetime as dt

# %%
from google.cloud import storage

def list_blobs(bucket_name, prefix):
    """Lists all the blobs in the bucket that match the prefix."""
    storage_client = storage.Client()
    blobs = storage_client.list_blobs(bucket_name, prefix=prefix)

    for blob in blobs:
        print(blob.name)

def download_blob(bucket_name, source_blob_name, destination_file_name):
    """Downloads a blob from the bucket."""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(source_blob_name)
    blob.download_to_filename(destination_file_name)
    print(f"Blob {source_blob_name} downloaded to {destination_file_name}.")

bucket_name = "my-project-bucket-ls"
prefix = "landing/"
list_blobs(bucket_name, prefix)
# Out:
# landing/D1/A.US_D1.csv
# landing/D1/AAL.US_D1.csv
# landing/D1/AAPL.US_D1.csv
# landing/D1/ABBV.US_D1.csv
# landing/D1/ABNB.US_D1.csv
# landing/D1/ABT.US_D1.csv
# landing/D1/ACGL.US_D1.csv
# landing/D1/ACN.US_D1.csv
# landing/D1/ADBE.US_D1.csv
# landing/D1/ADI.US_D1.csv
# landing/D1/ADM.US_D1.csv
# landing/D1/ADP.US_D1.csv
# landing/D1/ADSK.US_D1.csv
# landing/D1/AEE.US_D1.csv
# landing/D1/AEP.US_D1.csv
# landing/D1/AES.US_D1.csv
# landing/D1/AFL.US_D1.csv
# landing/D1/AIG.US_D1.csv
# landing/D1/AIZ.US_D1.csv
# landing/D1/AJG.US_D1.csv
# landing/D1/AKAM.US_D1.csv
# landing/D1/ALB.US_D1.csv
# landing/D1/ALGN.US_D1.csv
# landing/D1/ALL.US_D1.csv
# landing/D1/ALLE.US_D1.csv
# landing/D1/AMAT.US_D1.csv
# landing/D1/AMCR.US_D1.csv
# landing/D1/AMD.US_D1.csv
# landing/D1/AME.US_D1.csv
# landing/D1/AMGN.US_D1.csv
# landing/D1/AMP.US_D1.csv
# landing/D1/AMT.US_D1.csv
# landing/D1/AMZN.US_D1.csv
# landing/D1/ANET.US_D1.csv
# landing/D1/ANSS.US_D1.csv
# landing/D1/AON.US_D1.csv
# landing/D1/AOS.US_D1.csv
# landing/D1/APA.US_D1.csv
# landing/D1/APD.US_D1.csv
# landing/D1/APH.US_D1.csv
# landing/D1/APTV.US_D1.csv
# landing/D1/ARE.US_D1.csv
# landing/D1/ASML.US_D1.csv
# landing/D1/ATO.US_D1.csv
# landing/D1/AVB.US_D1.csv
# landing/D1/AVGO.US_D1.csv
# landing/D1/AVY.US_D1.csv
# landing/D1/AWK.US_D1.csv
# landing/D1/AXON.US_D1.csv
# landing/D1/AXP.US_D1.csv
# landing/D1/AZN.US_D1.csv
# landing/D1/AZO.US_D1.csv
# landing/D1/BA.US_D1.csv
# landing/D1/BAC.US_D1.csv
# landing/D1/BALL.US_D1.csv
# landing/D1/BAX.US_D1.csv
# landing/D1/BBWI.US_D1.csv
# landing/D1/BBY.US_D1.csv
# landing/D1/BDX.US_D1.csv
# landing/D1/BEN.US_D1.csv
# landing/D1/BF.B.US_D1.csv
# landing/D1/BG.US_D1.csv
# landing/D1/BIIB.US_D1.csv
# landing/D1/BIO.US_D1.csv
# landing/D1/BK.US_D1.csv
# landing/D1/BKNG.US_D1.csv
# landing/D1/BKR.US_D1.csv
# landing/D1/VRTX.US_D1.csv
# landing/D1/VTR.US_D1.csv
# landing/D1/VTRS.US_D1.csv
# landing/D1/VZ.US_D1.csv
# landing/D1/WAB.US_D1.csv
# landing/D1/WAT.US_D1.csv
# landing/D1/WBA.US_D1.csv
# landing/D1/WBD.US_D1.csv
# landing/D1/WDAY.US_D1.csv
# landing/D1/WDC.US_D1.csv
# landing/D1/WEC.US_D1.csv
# landing/D1/WELL.US_D1.csv
# landing/D1/WFC.US_D1.csv
# landing/D1/WHR.US_D1.csv
# landing/D1/WM.US_D1.csv
# landing/D1/WMB.US_D1.csv
# landing/D1/WMT.US_D1.csv
# landing/D1/WRB.US_D1.csv
# landing/D1/WRK.US_D1.csv
# landing/D1/WST.US_D1.csv
# landing/D1/WTW.US_D1.csv
# landing/D1/WY.US_D1.csv
# landing/D1/WYNN.US_D1.csv
# landing/D1/XEL.US_D1.csv
# landing/D1/XOM.US_D1.csv
# landing/D1/XRAY.US_D1.csv
# landing/D1/XYL.US_D1.csv
# landing/D1/YUM.US_D1.csv
# landing/D1/ZBH.US_D1.csv
# landing/D1/ZBRA.US_D1.csv
# landing/D1/ZION.US_D1.csv
# landing/D1/ZS.US_D1.csv
# landing/D1/ZTS.US_D1.csv

# %%
from google.cloud import storage
import pandas as pd
import os
from io import StringIO

storage_client = storage.Client()
bucket_name = 'my-project-bucket-ls'

def clean_and_save_df(df, filename, bucket_name):
    columns_to_keep = [
         'datetime', 'open', 'high', 'low', 'close', 'volume',
                    'bbands_20_upperband', 'bbands_20_middleband',
                    'bbands_20_lowerband', 'dema_20', 'ema_20', 'ema_60',
                    'kama_20', 'kama_60', 'ma_20', 'ma_60',
                    'sma_20', 'sma_60',
                    'tema_20', 'tema_60', 'adx_20', 'adx_60',
                    'macd_20_40_10_macd', 'macd_60_120_30_macd',
                    'rsi_20', 'rsi_60'
        ]
    df = df[columns_to_keep]
    
    df_cleaned = df.dropna().copy()    
    df_cleaned.loc[:, 'datetime'] = pd.to_datetime(df_cleaned['datetime'])
    
    parquet_bytes = df.to_parquet(index=False)
    
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(f'cleaned/{filename}.parquet')
    blob.upload_from_string(parquet_bytes, content_type='application/octet-stream')
    
    print(f'Cleaned data saved to cleaned/{filename}.parquet')

def process_all_csv(bucket_name, prefix):
    bucket = storage_client.get_bucket(bucket_name)
    blobs = bucket.list_blobs(prefix=prefix)
    
    for blob in blobs:
        if blob.name.endswith('.csv'):
            csv_string = blob.download_as_text()
            
            df = pd.read_csv(StringIO(csv_string))
            
            filename = os.path.splitext(os.path.basename(blob.name))[0] 
            clean_and_save_df(df, filename, bucket_name)

process_all_csv(bucket_name, 'landing/')


print("Data clean Complete.")
# Out:
# Cleaned data saved to cleaned/A.US_D1.parquet
# Cleaned data saved to cleaned/AAL.US_D1.parquet
# Cleaned data saved to cleaned/AAPL.US_D1.parquet
# Cleaned data saved to cleaned/ABBV.US_D1.parquet
# Cleaned data saved to cleaned/ABNB.US_D1.parquet
# Cleaned data saved to cleaned/ABT.US_D1.parquet
# Cleaned data saved to cleaned/ACGL.US_D1.parquet
# Cleaned data saved to cleaned/ACN.US_D1.parquet
# Cleaned data saved to cleaned/ADBE.US_D1.parquet
# Cleaned data saved to cleaned/ADI.US_D1.parquet
# Cleaned data saved to cleaned/ADM.US_D1.parquet
# Cleaned data saved to cleaned/ADP.US_D1.parquet
# Cleaned data saved to cleaned/ADSK.US_D1.parquet
# Cleaned data saved to cleaned/AEE.US_D1.parquet
# Cleaned data saved to cleaned/AEP.US_D1.parquet
# Cleaned data saved to cleaned/AES.US_D1.parquet
# Cleaned data saved to cleaned/AFL.US_D1.parquet
# Cleaned data saved to cleaned/AIG.US_D1.parquet
# Cleaned data saved to cleaned/AIZ.US_D1.parquet
# Cleaned data saved to cleaned/AJG.US_D1.parquet
# Cleaned data saved to cleaned/AKAM.US_D1.parquet
# Cleaned data saved to cleaned/ALB.US_D1.parquet
# Cleaned data saved to cleaned/ALGN.US_D1.parquet
# Cleaned data saved to cleaned/ALL.US_D1.parquet
# Cleaned data saved to cleaned/ALLE.US_D1.parquet
# Cleaned data saved to cleaned/AMAT.US_D1.parquet
# Cleaned data saved to cleaned/AMCR.US_D1.parquet
# Cleaned data saved to cleaned/AMD.US_D1.parquet
# Cleaned data saved to cleaned/AME.US_D1.parquet
# Cleaned data saved to cleaned/AMGN.US_D1.parquet
# Cleaned data saved to cleaned/AMP.US_D1.parquet
# Cleaned data saved to cleaned/AMT.US_D1.parquet
# Cleaned data saved to cleaned/AMZN.US_D1.parquet
# Cleaned data saved to cleaned/ANET.US_D1.parquet
# Cleaned data saved to cleaned/ANSS.US_D1.parquet
# Cleaned data saved to cleaned/AON.US_D1.parquet
# Cleaned data saved to cleaned/AOS.US_D1.parquet
# Cleaned data saved to cleaned/APA.US_D1.parquet
# Cleaned data saved to cleaned/APD.US_D1.parquet
# Cleaned data saved to cleaned/APH.US_D1.parquet
# Cleaned data saved to cleaned/APTV.US_D1.parquet
# Cleaned data saved to cleaned/ARE.US_D1.parquet
# Cleaned data saved to cleaned/ASML.US_D1.parquet
# Cleaned data saved to cleaned/ATO.US_D1.parquet
# Cleaned data saved to cleaned/AVB.US_D1.parquet
# Cleaned data saved to cleaned/AVGO.US_D1.parquet
# Cleaned data saved to cleaned/AVY.US_D1.parquet
# Cleaned data saved to cleaned/AWK.US_D1.parquet
# Cleaned data saved to cleaned/AXON.US_D1.parquet
# Cleaned data saved to cleaned/AXP.US_D1.parquet
# Cleaned data saved to cleaned/AZN.US_D1.parquet
# Cleaned data saved to cleaned/AZO.US_D1.parquet
# Cleaned data saved to cleaned/BA.US_D1.parquet
# Cleaned data saved to cleaned/BAC.US_D1.parquet
# Cleaned data saved to cleaned/BALL.US_D1.parquet
# Cleaned data saved to cleaned/BAX.US_D1.parquet
# Cleaned data saved to cleaned/BBWI.US_D1.parquet
# Cleaned data saved to cleaned/BBY.US_D1.parquet
# Cleaned data saved to cleaned/BDX.US_D1.parquet
# Cleaned data saved to cleaned/BEN.US_D1.parquet
# Cleaned data saved to cleaned/BF.B.US_D1.parquet
# Cleaned data saved to cleaned/BG.US_D1.parquet
# Cleaned data saved to cleaned/BIIB.US_D1.parquet
# Cleaned data saved to cleaned/BIO.US_D1.parquet
# Cleaned data saved to cleaned/BK.US_D1.parquet
# Cleaned data saved to cleaned/BKNG.US_D1.parquet
# Cleaned data saved to cleaned/BKR.US_D1.parquet
# Cleaned data saved to cleaned/BLDR.US_D1.parquet
# Cleaned data saved to cleaned/BLK.US_D1.parquet
# Cleaned data saved to cleaned/BMY.US_D1.parquet
# Cleaned data saved to cleaned/BR.US_D1.parquet
# Cleaned data saved to cleaned/BRK.B.US_D1.parquet
# Cleaned data saved to cleaned/BRO.US_D1.parquet
# Cleaned data saved to cleaned/BSX.US_D1.parquet
# Cleaned data saved to cleaned/BWA.US_D1.parquet
# Cleaned data saved to cleaned/BX.US_D1.parquet
# Cleaned data saved to cleaned/BXP.US_D1.parquet
# Cleaned data saved to cleaned/C.US_D1.parquet
# Cleaned data saved to cleaned/CAG.US_D1.parquet
# Cleaned data saved to cleaned/CAH.US_D1.parquet
# Cleaned data saved to cleaned/CARR.US_D1.parquet
# Cleaned data saved to cleaned/CAT.US_D1.parquet
# Cleaned data saved to cleaned/CB.US_D1.parquet
# Cleaned data saved to cleaned/CBOE.US_D1.parquet
# Cleaned data saved to cleaned/CBRE.US_D1.parquet
# Cleaned data saved to cleaned/CCEP.US_D1.parquet
# Cleaned data saved to cleaned/CCI.US_D1.parquet
# Cleaned data saved to cleaned/CCL.US_D1.parquet
# Cleaned data saved to cleaned/CDAY.US_D1.parquet
# Cleaned data saved to cleaned/CDNS.US_D1.parquet
# Cleaned data saved to cleaned/CDW.US_D1.parquet
# Cleaned data saved to cleaned/CE.US_D1.parquet
# Cleaned data saved to cleaned/CEG.US_D1.parquet
# Cleaned data saved to cleaned/CF.US_D1.parquet
# Cleaned data saved to cleaned/CFG.US_D1.parquet
# Cleaned data saved to cleaned/CHD.US_D1.parquet
# Cleaned data saved to cleaned/CHRW.US_D1.parquet
# Cleaned data saved to cleaned/CHTR.US_D1.parquet
# Cleaned data saved to cleaned/CI.US_D1.parquet
# Cleaned data saved to cleaned/CINF.US_D1.parquet
# Cleaned data saved to cleaned/CL.US_D1.parquet
# Cleaned data saved to cleaned/CLX.US_D1.parquet
# Cleaned data saved to cleaned/CMA.US_D1.parquet
# Cleaned data saved to cleaned/CMCSA.US_D1.parquet
# Cleaned data saved to cleaned/CME.US_D1.parquet
# Cleaned data saved to cleaned/CMG.US_D1.parquet
# Cleaned data saved to cleaned/CMI.US_D1.parquet
# Cleaned data saved to cleaned/CMS.US_D1.parquet
# Cleaned data saved to cleaned/CNC.US_D1.parquet
# Cleaned data saved to cleaned/CNP.US_D1.parquet
# Cleaned data saved to cleaned/COF.US_D1.parquet
# Cleaned data saved to cleaned/COO.US_D1.parquet
# Cleaned data saved to cleaned/COP.US_D1.parquet
# Cleaned data saved to cleaned/COR.US_D1.parquet
# Cleaned data saved to cleaned/COST.US_D1.parquet
# Cleaned data saved to cleaned/CPB.US_D1.parquet
# Cleaned data saved to cleaned/CPRT.US_D1.parquet
# Cleaned data saved to cleaned/CPT.US_D1.parquet
# Cleaned data saved to cleaned/CRL.US_D1.parquet
# Cleaned data saved to cleaned/CRM.US_D1.parquet
# Cleaned data saved to cleaned/CRWD.US_D1.parquet
# Cleaned data saved to cleaned/CSCO.US_D1.parquet
# Cleaned data saved to cleaned/CSGP.US_D1.parquet
# Cleaned data saved to cleaned/CSX.US_D1.parquet
# Cleaned data saved to cleaned/CTAS.US_D1.parquet
# Cleaned data saved to cleaned/CTLT.US_D1.parquet
# Cleaned data saved to cleaned/CTRA.US_D1.parquet
# Cleaned data saved to cleaned/CTSH.US_D1.parquet
# Cleaned data saved to cleaned/CTVA.US_D1.parquet
# Cleaned data saved to cleaned/CVS.US_D1.parquet
# Cleaned data saved to cleaned/CVX.US_D1.parquet
# Cleaned data saved to cleaned/CZR.US_D1.parquet
# Cleaned data saved to cleaned/D.US_D1.parquet
# Cleaned data saved to cleaned/DAL.US_D1.parquet
# Cleaned data saved to cleaned/DASH.US_D1.parquet
# Cleaned data saved to cleaned/DD.US_D1.parquet
# Cleaned data saved to cleaned/DDOG.US_D1.parquet
# Cleaned data saved to cleaned/DE.US_D1.parquet
# Cleaned data saved to cleaned/DFS.US_D1.parquet
# Cleaned data saved to cleaned/DG.US_D1.parquet
# Cleaned data saved to cleaned/DGX.US_D1.parquet
# Cleaned data saved to cleaned/DHI.US_D1.parquet
# Cleaned data saved to cleaned/DHR.US_D1.parquet
# Cleaned data saved to cleaned/DIS.US_D1.parquet
# Cleaned data saved to cleaned/DLR.US_D1.parquet
# Cleaned data saved to cleaned/DLTR.US_D1.parquet
# Cleaned data saved to cleaned/DOV.US_D1.parquet
# Cleaned data saved to cleaned/DOW.US_D1.parquet
# Cleaned data saved to cleaned/DPZ.US_D1.parquet
# Cleaned data saved to cleaned/DRI.US_D1.parquet
# Cleaned data saved to cleaned/DTE.US_D1.parquet
# Cleaned data saved to cleaned/DUK.US_D1.parquet
# Cleaned data saved to cleaned/DVA.US_D1.parquet
# Cleaned data saved to cleaned/DVN.US_D1.parquet
# Cleaned data saved to cleaned/DXCM.US_D1.parquet
# Cleaned data saved to cleaned/EA.US_D1.parquet
# Cleaned data saved to cleaned/EBAY.US_D1.parquet
# Cleaned data saved to cleaned/ECL.US_D1.parquet
# Cleaned data saved to cleaned/ED.US_D1.parquet
# Cleaned data saved to cleaned/EFX.US_D1.parquet
# Cleaned data saved to cleaned/EIX.US_D1.parquet
# Cleaned data saved to cleaned/EL.US_D1.parquet
# Cleaned data saved to cleaned/EMN.US_D1.parquet
# Cleaned data saved to cleaned/EMR.US_D1.parquet
# Cleaned data saved to cleaned/ENPH.US_D1.parquet
# Cleaned data saved to cleaned/EOG.US_D1.parquet
# Cleaned data saved to cleaned/EPAM.US_D1.parquet
# Cleaned data saved to cleaned/EQIX.US_D1.parquet
# Cleaned data saved to cleaned/EQR.US_D1.parquet
# Cleaned data saved to cleaned/EQT.US_D1.parquet
# Cleaned data saved to cleaned/ES.US_D1.parquet
# Cleaned data saved to cleaned/ESS.US_D1.parquet
# Cleaned data saved to cleaned/ETN.US_D1.parquet
# Cleaned data saved to cleaned/ETR.US_D1.parquet
# Cleaned data saved to cleaned/ETSY.US_D1.parquet
# Cleaned data saved to cleaned/EVRG.US_D1.parquet
# Cleaned data saved to cleaned/EW.US_D1.parquet
# Cleaned data saved to cleaned/EXC.US_D1.parquet
# Cleaned data saved to cleaned/EXPD.US_D1.parquet
# Cleaned data saved to cleaned/EXPE.US_D1.parquet
# Cleaned data saved to cleaned/EXR.US_D1.parquet
# Cleaned data saved to cleaned/F.US_D1.parquet
# Cleaned data saved to cleaned/FANG.US_D1.parquet
# Cleaned data saved to cleaned/FAST.US_D1.parquet
# Cleaned data saved to cleaned/FCX.US_D1.parquet
# Cleaned data saved to cleaned/FDS.US_D1.parquet
# Cleaned data saved to cleaned/FDX.US_D1.parquet
# Cleaned data saved to cleaned/FE.US_D1.parquet
# Cleaned data saved to cleaned/FFIV.US_D1.parquet
# Cleaned data saved to cleaned/FI.US_D1.parquet
# Cleaned data saved to cleaned/FICO.US_D1.parquet
# Cleaned data saved to cleaned/FIS.US_D1.parquet
# Cleaned data saved to cleaned/FITB.US_D1.parquet
# Cleaned data saved to cleaned/FLT.US_D1.parquet
# Cleaned data saved to cleaned/FMC.US_D1.parquet
# Cleaned data saved to cleaned/FOX.US_D1.parquet
# Cleaned data saved to cleaned/FOXA.US_D1.parquet
# Cleaned data saved to cleaned/FRT.US_D1.parquet
# Cleaned data saved to cleaned/FSLR.US_D1.parquet
# Cleaned data saved to cleaned/FTNT.US_D1.parquet
# Cleaned data saved to cleaned/FTV.US_D1.parquet
# Cleaned data saved to cleaned/GD.US_D1.parquet
# Cleaned data saved to cleaned/GE.US_D1.parquet
# Cleaned data saved to cleaned/GEHC.US_D1.parquet
# Cleaned data saved to cleaned/GEN.US_D1.parquet
# Cleaned data saved to cleaned/GILD.US_D1.parquet
# Cleaned data saved to cleaned/GIS.US_D1.parquet
# Cleaned data saved to cleaned/GL.US_D1.parquet
# Cleaned data saved to cleaned/GLW.US_D1.parquet
# Cleaned data saved to cleaned/GM.US_D1.parquet
# Cleaned data saved to cleaned/GNRC.US_D1.parquet
# Cleaned data saved to cleaned/GOOG.US_D1.parquet
# Cleaned data saved to cleaned/GOOGL.US_D1.parquet
# Cleaned data saved to cleaned/GPC.US_D1.parquet
# Cleaned data saved to cleaned/GPN.US_D1.parquet
# Cleaned data saved to cleaned/GRMN.US_D1.parquet
# Cleaned data saved to cleaned/GS.US_D1.parquet
# Cleaned data saved to cleaned/GWW.US_D1.parquet
# Cleaned data saved to cleaned/HAL.US_D1.parquet
# Cleaned data saved to cleaned/HAS.US_D1.parquet
# Cleaned data saved to cleaned/HBAN.US_D1.parquet
# Cleaned data saved to cleaned/HCA.US_D1.parquet
# Cleaned data saved to cleaned/HD.US_D1.parquet
# Cleaned data saved to cleaned/HES.US_D1.parquet
# Cleaned data saved to cleaned/HIG.US_D1.parquet
# Cleaned data saved to cleaned/HII.US_D1.parquet
# Cleaned data saved to cleaned/HLT.US_D1.parquet
# Cleaned data saved to cleaned/HOLX.US_D1.parquet
# Cleaned data saved to cleaned/HON.US_D1.parquet
# Cleaned data saved to cleaned/HPE.US_D1.parquet
# Cleaned data saved to cleaned/HPQ.US_D1.parquet
# Cleaned data saved to cleaned/HRL.US_D1.parquet
# Cleaned data saved to cleaned/HSIC.US_D1.parquet
# Cleaned data saved to cleaned/HST.US_D1.parquet
# Cleaned data saved to cleaned/HSY.US_D1.parquet
# Cleaned data saved to cleaned/HUBB.US_D1.parquet
# Cleaned data saved to cleaned/HUM.US_D1.parquet
# Cleaned data saved to cleaned/HWM.US_D1.parquet
# Cleaned data saved to cleaned/IBM.US_D1.parquet
# Cleaned data saved to cleaned/ICE.US_D1.parquet
# Cleaned data saved to cleaned/IDXX.US_D1.parquet
# Cleaned data saved to cleaned/IEX.US_D1.parquet
# Cleaned data saved to cleaned/IFF.US_D1.parquet
# Cleaned data saved to cleaned/ILMN.US_D1.parquet
# Cleaned data saved to cleaned/INCY.US_D1.parquet
# Cleaned data saved to cleaned/INTC.US_D1.parquet
# Cleaned data saved to cleaned/INTU.US_D1.parquet
# Cleaned data saved to cleaned/INVH.US_D1.parquet
# Cleaned data saved to cleaned/IP.US_D1.parquet
# Cleaned data saved to cleaned/IPG.US_D1.parquet
# Cleaned data saved to cleaned/IQV.US_D1.parquet
# Cleaned data saved to cleaned/IR.US_D1.parquet
# Cleaned data saved to cleaned/IRM.US_D1.parquet
# Cleaned data saved to cleaned/ISRG.US_D1.parquet
# Cleaned data saved to cleaned/IT.US_D1.parquet
# Cleaned data saved to cleaned/ITW.US_D1.parquet
# Cleaned data saved to cleaned/IVZ.US_D1.parquet
# Cleaned data saved to cleaned/J.US_D1.parquet
# Cleaned data saved to cleaned/JBHT.US_D1.parquet
# Cleaned data saved to cleaned/JBL.US_D1.parquet
# Cleaned data saved to cleaned/JCI.US_D1.parquet
# Cleaned data saved to cleaned/JKHY.US_D1.parquet
# Cleaned data saved to cleaned/JNJ.US_D1.parquet
# Cleaned data saved to cleaned/JNPR.US_D1.parquet
# Cleaned data saved to cleaned/JPM.US_D1.parquet
# Cleaned data saved to cleaned/K.US_D1.parquet
# Cleaned data saved to cleaned/KDP.US_D1.parquet
# Cleaned data saved to cleaned/KEY.US_D1.parquet
# Cleaned data saved to cleaned/KEYS.US_D1.parquet
# Cleaned data saved to cleaned/KHC.US_D1.parquet
# Cleaned data saved to cleaned/KIM.US_D1.parquet
# Cleaned data saved to cleaned/KLAC.US_D1.parquet
# Cleaned data saved to cleaned/KMB.US_D1.parquet
# Cleaned data saved to cleaned/KMI.US_D1.parquet
# Cleaned data saved to cleaned/KMX.US_D1.parquet
# Cleaned data saved to cleaned/KO.US_D1.parquet
# Cleaned data saved to cleaned/KR.US_D1.parquet
# Cleaned data saved to cleaned/L.US_D1.parquet
# Cleaned data saved to cleaned/LDOS.US_D1.parquet
# Cleaned data saved to cleaned/LEN.US_D1.parquet
# Cleaned data saved to cleaned/LH.US_D1.parquet
# Cleaned data saved to cleaned/LHX.US_D1.parquet
# Cleaned data saved to cleaned/LIN.US_D1.parquet
# Cleaned data saved to cleaned/LKQ.US_D1.parquet
# Cleaned data saved to cleaned/LLY.US_D1.parquet
# Cleaned data saved to cleaned/LMT.US_D1.parquet
# Cleaned data saved to cleaned/LNT.US_D1.parquet
# Cleaned data saved to cleaned/LOW.US_D1.parquet
# Cleaned data saved to cleaned/LRCX.US_D1.parquet
# Cleaned data saved to cleaned/LULU.US_D1.parquet
# Cleaned data saved to cleaned/LUV.US_D1.parquet
# Cleaned data saved to cleaned/LVS.US_D1.parquet
# Cleaned data saved to cleaned/LW.US_D1.parquet
# Cleaned data saved to cleaned/LYB.US_D1.parquet
# Cleaned data saved to cleaned/LYV.US_D1.parquet
# Cleaned data saved to cleaned/MA.US_D1.parquet
# Cleaned data saved to cleaned/MAA.US_D1.parquet
# Cleaned data saved to cleaned/MAR.US_D1.parquet
# Cleaned data saved to cleaned/MAS.US_D1.parquet
# Cleaned data saved to cleaned/MCD.US_D1.parquet
# Cleaned data saved to cleaned/MCHP.US_D1.parquet
# Cleaned data saved to cleaned/MCK.US_D1.parquet
# Cleaned data saved to cleaned/MCO.US_D1.parquet
# Cleaned data saved to cleaned/MDB.US_D1.parquet
# Cleaned data saved to cleaned/MDLZ.US_D1.parquet
# Cleaned data saved to cleaned/MDT.US_D1.parquet
# Cleaned data saved to cleaned/MELI.US_D1.parquet
# Cleaned data saved to cleaned/MET.US_D1.parquet
# Cleaned data saved to cleaned/META.US_D1.parquet
# Cleaned data saved to cleaned/MGM.US_D1.parquet
# Cleaned data saved to cleaned/MHK.US_D1.parquet
# Cleaned data saved to cleaned/MKC.US_D1.parquet
# Cleaned data saved to cleaned/MKTX.US_D1.parquet
# Cleaned data saved to cleaned/MLM.US_D1.parquet
# Cleaned data saved to cleaned/MMC.US_D1.parquet
# Cleaned data saved to cleaned/MMM.US_D1.parquet
# Cleaned data saved to cleaned/MNST.US_D1.parquet
# Cleaned data saved to cleaned/MO.US_D1.parquet
# Cleaned data saved to cleaned/MOH.US_D1.parquet
# Cleaned data saved to cleaned/MOS.US_D1.parquet
# Cleaned data saved to cleaned/MPC.US_D1.parquet
# Cleaned data saved to cleaned/MPWR.US_D1.parquet
# Cleaned data saved to cleaned/MRK.US_D1.parquet
# Cleaned data saved to cleaned/MRNA.US_D1.parquet
# Cleaned data saved to cleaned/MRO.US_D1.parquet
# Cleaned data saved to cleaned/MRVL.US_D1.parquet
# Cleaned data saved to cleaned/MS.US_D1.parquet
# Cleaned data saved to cleaned/MSCI.US_D1.parquet
# Cleaned data saved to cleaned/MSFT.US_D1.parquet
# Cleaned data saved to cleaned/MSI.US_D1.parquet
# Cleaned data saved to cleaned/MTB.US_D1.parquet
# Cleaned data saved to cleaned/MTCH.US_D1.parquet
# Cleaned data saved to cleaned/MTD.US_D1.parquet
# Cleaned data saved to cleaned/MU.US_D1.parquet
# Cleaned data saved to cleaned/NCLH.US_D1.parquet
# Cleaned data saved to cleaned/NDAQ.US_D1.parquet
# Cleaned data saved to cleaned/NDSN.US_D1.parquet
# Cleaned data saved to cleaned/NEE.US_D1.parquet
# Cleaned data saved to cleaned/NEM.US_D1.parquet
# Cleaned data saved to cleaned/NFLX.US_D1.parquet
# Cleaned data saved to cleaned/NI.US_D1.parquet
# Cleaned data saved to cleaned/NKE.US_D1.parquet
# Cleaned data saved to cleaned/NOC.US_D1.parquet
# Cleaned data saved to cleaned/NOW.US_D1.parquet
# Cleaned data saved to cleaned/NRG.US_D1.parquet
# Cleaned data saved to cleaned/NSC.US_D1.parquet
# Cleaned data saved to cleaned/NTAP.US_D1.parquet
# Cleaned data saved to cleaned/NTRS.US_D1.parquet
# Cleaned data saved to cleaned/NUE.US_D1.parquet
# Cleaned data saved to cleaned/NVDA.US_D1.parquet
# Cleaned data saved to cleaned/NVR.US_D1.parquet
# Cleaned data saved to cleaned/NWS.US_D1.parquet
# Cleaned data saved to cleaned/NWSA.US_D1.parquet
# Cleaned data saved to cleaned/NXPI.US_D1.parquet
# Cleaned data saved to cleaned/O.US_D1.parquet
# Cleaned data saved to cleaned/ODFL.US_D1.parquet
# Cleaned data saved to cleaned/OKE.US_D1.parquet
# Cleaned data saved to cleaned/OMC.US_D1.parquet
# Cleaned data saved to cleaned/ON.US_D1.parquet
# Cleaned data saved to cleaned/ORCL.US_D1.parquet
# Cleaned data saved to cleaned/ORLY.US_D1.parquet
# Cleaned data saved to cleaned/OTIS.US_D1.parquet
# Cleaned data saved to cleaned/OXY.US_D1.parquet
# Cleaned data saved to cleaned/PANW.US_D1.parquet
# Cleaned data saved to cleaned/PARA.US_D1.parquet
# Cleaned data saved to cleaned/PAYC.US_D1.parquet
# Cleaned data saved to cleaned/PAYX.US_D1.parquet
# Cleaned data saved to cleaned/PCAR.US_D1.parquet
# Cleaned data saved to cleaned/PCG.US_D1.parquet
# Cleaned data saved to cleaned/PDD.US_D1.parquet
# Cleaned data saved to cleaned/PEAK.US_D1.parquet
# Cleaned data saved to cleaned/PEG.US_D1.parquet
# Cleaned data saved to cleaned/PEP.US_D1.parquet
# Cleaned data saved to cleaned/PFE.US_D1.parquet
# Cleaned data saved to cleaned/PFG.US_D1.parquet
# Cleaned data saved to cleaned/PG.US_D1.parquet
# Cleaned data saved to cleaned/PGR.US_D1.parquet
# Cleaned data saved to cleaned/PH.US_D1.parquet
# Cleaned data saved to cleaned/PHM.US_D1.parquet
# Cleaned data saved to cleaned/PKG.US_D1.parquet
# Cleaned data saved to cleaned/PLD.US_D1.parquet
# Cleaned data saved to cleaned/PM.US_D1.parquet
# Cleaned data saved to cleaned/PNC.US_D1.parquet
# Cleaned data saved to cleaned/PNR.US_D1.parquet
# Cleaned data saved to cleaned/PNW.US_D1.parquet
# Cleaned data saved to cleaned/PODD.US_D1.parquet
# Cleaned data saved to cleaned/POOL.US_D1.parquet
# Cleaned data saved to cleaned/PPG.US_D1.parquet
# Cleaned data saved to cleaned/PPL.US_D1.parquet
# Cleaned data saved to cleaned/PRU.US_D1.parquet
# Cleaned data saved to cleaned/PSA.US_D1.parquet
# Cleaned data saved to cleaned/PSX.US_D1.parquet
# Cleaned data saved to cleaned/PTC.US_D1.parquet
# Cleaned data saved to cleaned/PWR.US_D1.parquet
# Cleaned data saved to cleaned/PXD.US_D1.parquet
# Cleaned data saved to cleaned/PYPL.US_D1.parquet
# Cleaned data saved to cleaned/QCOM.US_D1.parquet
# Cleaned data saved to cleaned/QRVO.US_D1.parquet
# Cleaned data saved to cleaned/RCL.US_D1.parquet
# Cleaned data saved to cleaned/REG.US_D1.parquet
# Cleaned data saved to cleaned/REGN.US_D1.parquet
# Cleaned data saved to cleaned/RF.US_D1.parquet
# Cleaned data saved to cleaned/RHI.US_D1.parquet
# Cleaned data saved to cleaned/RJF.US_D1.parquet
# Cleaned data saved to cleaned/RL.US_D1.parquet
# Cleaned data saved to cleaned/RMD.US_D1.parquet
# Cleaned data saved to cleaned/ROK.US_D1.parquet
# Cleaned data saved to cleaned/ROL.US_D1.parquet
# Cleaned data saved to cleaned/ROP.US_D1.parquet
# Cleaned data saved to cleaned/ROST.US_D1.parquet
# Cleaned data saved to cleaned/RSG.US_D1.parquet
# Cleaned data saved to cleaned/RTX.US_D1.parquet
# Cleaned data saved to cleaned/SBAC.US_D1.parquet
# Cleaned data saved to cleaned/SBUX.US_D1.parquet
# Cleaned data saved to cleaned/SCHW.US_D1.parquet
# Cleaned data saved to cleaned/SHW.US_D1.parquet
# Cleaned data saved to cleaned/SIRI.US_D1.parquet
# Cleaned data saved to cleaned/SJM.US_D1.parquet
# Cleaned data saved to cleaned/SLB.US_D1.parquet
# Cleaned data saved to cleaned/SNA.US_D1.parquet
# Cleaned data saved to cleaned/SNPS.US_D1.parquet
# Cleaned data saved to cleaned/SO.US_D1.parquet
# Cleaned data saved to cleaned/SPG.US_D1.parquet
# Cleaned data saved to cleaned/SPGI.US_D1.parquet
# Cleaned data saved to cleaned/SPLK.US_D1.parquet
# Cleaned data saved to cleaned/SRE.US_D1.parquet
# Cleaned data saved to cleaned/STE.US_D1.parquet
# Cleaned data saved to cleaned/STLD.US_D1.parquet
# Cleaned data saved to cleaned/STT.US_D1.parquet
# Cleaned data saved to cleaned/STX.US_D1.parquet
# Cleaned data saved to cleaned/STZ.US_D1.parquet
# Cleaned data saved to cleaned/SWK.US_D1.parquet
# Cleaned data saved to cleaned/SWKS.US_D1.parquet
# Cleaned data saved to cleaned/SYF.US_D1.parquet
# Cleaned data saved to cleaned/SYK.US_D1.parquet
# Cleaned data saved to cleaned/SYY.US_D1.parquet
# Cleaned data saved to cleaned/T.US_D1.parquet
# Cleaned data saved to cleaned/TAP.US_D1.parquet
# Cleaned data saved to cleaned/TDG.US_D1.parquet
# Cleaned data saved to cleaned/TDY.US_D1.parquet
# Cleaned data saved to cleaned/TEAM.US_D1.parquet
# Cleaned data saved to cleaned/TECH.US_D1.parquet
# Cleaned data saved to cleaned/TEL.US_D1.parquet
# Cleaned data saved to cleaned/TER.US_D1.parquet
# Cleaned data saved to cleaned/TFC.US_D1.parquet
# Cleaned data saved to cleaned/TFX.US_D1.parquet
# Cleaned data saved to cleaned/TGT.US_D1.parquet
# Cleaned data saved to cleaned/TJX.US_D1.parquet
# Cleaned data saved to cleaned/TMO.US_D1.parquet
# Cleaned data saved to cleaned/TMUS.US_D1.parquet
# Cleaned data saved to cleaned/TPR.US_D1.parquet
# Cleaned data saved to cleaned/TRGP.US_D1.parquet
# Cleaned data saved to cleaned/TRMB.US_D1.parquet
# Cleaned data saved to cleaned/TROW.US_D1.parquet
# Cleaned data saved to cleaned/TRV.US_D1.parquet
# Cleaned data saved to cleaned/TSCO.US_D1.parquet
# Cleaned data saved to cleaned/TSLA.US_D1.parquet
# Cleaned data saved to cleaned/TSN.US_D1.parquet
# Cleaned data saved to cleaned/TT.US_D1.parquet
# Cleaned data saved to cleaned/TTD.US_D1.parquet
# Cleaned data saved to cleaned/TTWO.US_D1.parquet
# Cleaned data saved to cleaned/TXN.US_D1.parquet
# Cleaned data saved to cleaned/TXT.US_D1.parquet
# Cleaned data saved to cleaned/TYL.US_D1.parquet
# Cleaned data saved to cleaned/UAL.US_D1.parquet
# Cleaned data saved to cleaned/UBER.US_D1.parquet
# Cleaned data saved to cleaned/UDR.US_D1.parquet
# Cleaned data saved to cleaned/UHS.US_D1.parquet
# Cleaned data saved to cleaned/ULTA.US_D1.parquet
# Cleaned data saved to cleaned/UNH.US_D1.parquet
# Cleaned data saved to cleaned/UNP.US_D1.parquet
# Cleaned data saved to cleaned/UPS.US_D1.parquet
# Cleaned data saved to cleaned/URI.US_D1.parquet
# Cleaned data saved to cleaned/USB.US_D1.parquet
# Cleaned data saved to cleaned/V.US_D1.parquet
# Cleaned data saved to cleaned/VFC.US_D1.parquet
# Cleaned data saved to cleaned/VICI.US_D1.parquet
# Cleaned data saved to cleaned/VLO.US_D1.parquet
# Cleaned data saved to cleaned/VMC.US_D1.parquet
# Cleaned data saved to cleaned/VRSK.US_D1.parquet
# Cleaned data saved to cleaned/VRSN.US_D1.parquet
# Cleaned data saved to cleaned/VRTX.US_D1.parquet
# Cleaned data saved to cleaned/VTR.US_D1.parquet
# Cleaned data saved to cleaned/VTRS.US_D1.parquet
# Cleaned data saved to cleaned/VZ.US_D1.parquet
# Cleaned data saved to cleaned/WAB.US_D1.parquet
# Cleaned data saved to cleaned/WAT.US_D1.parquet
# Cleaned data saved to cleaned/WBA.US_D1.parquet
# Cleaned data saved to cleaned/WBD.US_D1.parquet
# Cleaned data saved to cleaned/WDAY.US_D1.parquet
# Cleaned data saved to cleaned/WDC.US_D1.parquet
# Cleaned data saved to cleaned/WEC.US_D1.parquet
# Cleaned data saved to cleaned/WELL.US_D1.parquet
# Cleaned data saved to cleaned/WFC.US_D1.parquet
# Cleaned data saved to cleaned/WHR.US_D1.parquet
# Cleaned data saved to cleaned/WM.US_D1.parquet
# Cleaned data saved to cleaned/WMB.US_D1.parquet
# Cleaned data saved to cleaned/WMT.US_D1.parquet
# Cleaned data saved to cleaned/WRB.US_D1.parquet
# Cleaned data saved to cleaned/WRK.US_D1.parquet
# Cleaned data saved to cleaned/WST.US_D1.parquet
# Cleaned data saved to cleaned/WTW.US_D1.parquet
# Cleaned data saved to cleaned/WY.US_D1.parquet
# Cleaned data saved to cleaned/WYNN.US_D1.parquet
# Cleaned data saved to cleaned/XEL.US_D1.parquet
# Cleaned data saved to cleaned/XOM.US_D1.parquet
# Cleaned data saved to cleaned/XRAY.US_D1.parquet
# Cleaned data saved to cleaned/XYL.US_D1.parquet
# Cleaned data saved to cleaned/YUM.US_D1.parquet
# Cleaned data saved to cleaned/ZBH.US_D1.parquet
# Cleaned data saved to cleaned/ZBRA.US_D1.parquet
# Cleaned data saved to cleaned/ZION.US_D1.parquet
# Cleaned data saved to cleaned/ZS.US_D1.parquet
# Cleaned data saved to cleaned/ZTS.US_D1.parquet
# Data clean Complete.
